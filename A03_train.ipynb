# %% [markdown]
# # 03 Train

# %% [markdown]
# #### Connect to GD

# %%
# set up connection to your google drive
# please click on the link generated and enter the authorisation code

from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Colab/statbot

# %%
# Install / update spacy
# update spacy
! pip install -U spacy
! python -m spacy info

# %%
# load German model
! python -m spacy download de_core_news_lg

# %% [markdown]
# ## DISCLAIMER:
# A large part of this code for training new entities, based on a pre-trained model, is taken from Isaac Aderogba:  https://deepnote.com/publish/2cc2d19c-c3ac-4321-8853-0bcf2ef565b3 Statistics Canton Zurich humbly tried to adapt his code for our purposes of training statistically relevant entities.
#
# ## Script A03
# Training is being done based on a pre-trained German bert-base-multilingual-cased model by using transfer learning. At the end of the script there is also an evaluation of the tags. This includes both the previously included NER tags and the new NER tags, as transfer learning can change the accuracy of previously learned tags.
#
# As large parts of this code have been taken from the link mentioned above, we recommend reading it. We consider it the best possible tutorial for this task.
#
# ## Thoughts for improvement
# - **add link for POS** (Position of Speech)

# %%
from __future__ import print_function, unicode_literals
import spacy
import warnings
from spacy.util import minibatch, compounding
import de_core_news_lg
import pandas as pd
import numpy as np
from random import sample
import io, csv
import re
import random
import json
from spacy.training import Example
from spacy.tokens import Doc
from tqdm import tqdm
nlp = spacy.load('de_core_news_lg')
#nlp = spacy.load('de_dep_news_trf')

# %%
# helper function for incrementing the revision counters
def increment_revision_counters(entity_counter, entities):
    for entity in entities:
        label = entity[2]
        if label in entity_counter:
            entity_counter[label] += 1
        else:
            entity_counter[label] = 1

# %%
with open('input/tagged_sentences_latest.json') as json_file:
    out_sentences = json.load(json_file)
print("LENGTH OF DATASET: ",len(out_sentences))
dataset_dict={}

for sent in out_sentences:
    entities = sent[1]["entities"]
    increment_revision_counters(dataset_dict, entities)

print(dataset_dict)
# Out:
# LENGTH OF DATASET:  1994
# {'GRAN': 1975, 'PLACE': 1108, 'TIME': 1797}

# %% [markdown]
# was:
# LENGTH OF DATASET:  1020
# {'DATA': 1010, 'GRAN': 279}
#
# is:
# LENGTH OF DATASET:  1994
# {'GRAN': 1975, 'PLACE': 1108, 'TIME': 1797}

# %%
npr_df = pd.read_csv("external/deu_news_2015_3M-sentences.txt", delimiter = "\t")
npr_df = npr_df.sample(frac=1)
npr_df.head()
# Out:
#                1                                                  ­
# 1490388  1568949  Ich bekam alle PIs immer zum offizellen (günst...
# 767534    802840                          Derzeit gilt das Dementi.
# 1215075  1277959  Er hofft, dass der Familie „Gerechtigkeit in F...
# 1205479  1267903  Er fiel damit aber dennoch ebenso wie der Gewi...
# 1594178  1683295  In der FireEye-Studie wurde auch untersucht, w...

# %%
# *** <- löschen?
# create an nlp object as we'll use this to seperate the sentences and identify existing entities
#loaded already above
#nlp = spacy.load('de_core_news_lg')

# %%
revision_texts = []

#STAT: Important: THIS IS A HYPER-PARAMETER: Changing it will affect the accuracy of the result
hyper_para_how_many = 100000

# convert the articles to spacy objects to better identify the sentences. Disabled unneeded components. # takes ~ 4 minutes
for doc in tqdm(nlp.pipe(npr_df.iloc[:hyper_para_how_many,1], batch_size=30, disable=["tagger", "ner"])):
    for sentence in doc.sents:

        if  40 < len(sentence.text) < 80:
            # some of the sentences had excessive whitespace in between words, so we're trimming that
            revision_texts.append(" ".join(re.split("\s+", sentence.text, flags=re.UNICODE)))
# Out:
# 100000it [04:16, 390.06it/s]

# %%
revisions = []

# Use the existing spaCy model to predict the entities, then append them to revision
for doc in nlp.pipe(revision_texts, batch_size=50, disable=["tagger", "parser"]):
    
    # don't append sentences that have no entities
    if len(doc.ents) > 0:
        revisions.append((doc.text, {"entities": [(e.start_char, e.end_char, e.label_) for e in doc.ents]}))

# %%
# print an example of the revision sentence
print(revisions[0][0])

# print an example of the revision data
print(revisions[0][1])
# Out:
# Ich bekam alle PIs immer zum offizellen (günstigen) Preis.
# {'entities': [(15, 18, 'ORG')]}

# %%
# create arrays to store the revision data
TRAIN_REVISION_DATA = []
TEST_REVISION_DATA = []

# create dictionaries to keep count of the different entities
TRAIN_ENTITY_COUNTER = {}
TEST_ENTITY_COUNTER = {}

# This will help distribute the entities (i.e. we don't want 1000 PERSON entities, but only 80 ORG entities)
REVISION_SENTENCE_SOFT_LIMIT = 100



random.shuffle(revisions)
for revision in revisions:
    # get the entities from the revision sentence
    entities = revision[1]["entities"]

    # simple hack to make sure spaCy entities don't get too one-sided
    should_append_to_train_counter = 0
    for _, _, label in entities:
        if label in TRAIN_ENTITY_COUNTER and TRAIN_ENTITY_COUNTER[label] > REVISION_SENTENCE_SOFT_LIMIT:
            should_append_to_train_counter -= 1
        else:
            should_append_to_train_counter += 1

    # simple switch for deciding whether to append to train data or test data
    if should_append_to_train_counter >= 0:
        TRAIN_REVISION_DATA.append(revision)
        increment_revision_counters(TRAIN_ENTITY_COUNTER, entities)
    else:
        TEST_REVISION_DATA.append(revision)
        increment_revision_counters(TEST_ENTITY_COUNTER, entities)

# %%
TRAIN_ENTITY_COUNTER
# Out:
# {'LOC': 103, 'PER': 101, 'ORG': 101, 'MISC': 105}

# %%
TEST_ENTITY_COUNTER
# Out:
# {'LOC': 8100, 'MISC': 7619, 'PER': 7190, 'ORG': 6111}

# %%
#TRAIN_REVISION_DATA

# %%
random.shuffle(out_sentences)
TRAIN_STAT_DATA = out_sentences[:int(len(out_sentences)*0.8)]
TEST_STAT_DATA = out_sentences[int(len(out_sentences)*0.8):]

# %%
print(len(out_sentences))
print(len(TRAIN_STAT_DATA))
print(len(TEST_STAT_DATA))
print("REVISION", len(TRAIN_REVISION_DATA))
TRAIN_DATA = TRAIN_REVISION_DATA + TRAIN_STAT_DATA
print("COMBINED", len(TRAIN_DATA))
# Out:
# 1994
# 1595
# 399
# REVISION 302
# COMBINED 1897

# %%
#STAT: below is the heart piece of this script, and the code was heavily changed compared to the original
#script taken out of the code on deepnote.com. The reason is thaat this code has been adapted to spacy 3 -
#while the old code was running on spacy 2.X
#central command is nlp-update

ner = nlp.get_pipe("ner")

ner.add_label("GRAN")
ner.add_label("PLACE")
ner.add_label("TIME")



# get the names of the components we want to disable during training
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# start the training loop, only training NER
epochs = 30
#optimizer = nlp.resume_training()
#optimizer = nlp.initialize()
with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
    warnings.filterwarnings("once", category=UserWarning, module='spacy')
    sizes = compounding(1.0, 4.0, 1.001)
    
    # batch up the examples using spaCy's minibatc
    for epoch in range(epochs):
        random.shuffle(TRAIN_DATA)
        #text = []
        #annots=[]
        examples=[]


        for text,annots in TRAIN_DATA:
            #text.append(t)
            #annots.append(a)
            doc = nlp.make_doc(text)    
            example = Example.from_dict(doc, annots)
            examples.append(example)
        
        losses = {}
        
        nlp.update(examples, drop=0.35, losses=losses)#,sgd=optimizer)

        print("Losses ({}/{})".format(epoch + 1, epochs), losses)
# Out:
# Losses (1/30) {'ner': 10188.581264753471}
# Losses (2/30) {'ner': 9459.908174538683}
# Losses (3/30) {'ner': 9445.161129288601}
# Losses (4/30) {'ner': 8518.027787385525}
# Losses (5/30) {'ner': 8155.618985515837}
# Losses (6/30) {'ner': 7793.852555083678}
# Losses (7/30) {'ner': 7409.679811059817}
# Losses (8/30) {'ner': 7071.3765016312245}
# Losses (9/30) {'ner': 6832.3976974316465}
# Losses (10/30) {'ner': 6610.7764019127935}
# Losses (11/30) {'ner': 6486.39326103963}
# Losses (12/30) {'ner': 6388.479219406843}
# Losses (13/30) {'ner': 6251.890470008366}
# Losses (14/30) {'ner': 6137.559721636819}
# Losses (15/30) {'ner': 6188.17859888915}
# Losses (16/30) {'ner': 5948.965543565224}
# Losses (17/30) {'ner': 5844.305143623031}
# Losses (18/30) {'ner': 5784.865281918785}
# Losses (19/30) {'ner': 5640.480599898321}
# Losses (20/30) {'ner': 5564.7798543042445}
# Losses (21/30) {'ner': 5366.312321403268}
# Losses (22/30) {'ner': 5131.844826805509}
# Losses (23/30) {'ner': 5202.985088239817}
# Losses (24/30) {'ner': 4873.593205159825}
# Losses (25/30) {'ner': 4814.901107338988}
# Losses (26/30) {'ner': 4813.857837897114}
# Losses (27/30) {'ner': 4605.187746152769}
# Losses (28/30) {'ner': 4424.6503486833435}
# Losses (29/30) {'ner': 4353.155389770135}
# Losses (30/30) {'ner': 4391.859477208868}

# %%
statbot_colors = {"GRAN": "linear-gradient(90deg, #aa9cfc, #fc9ce7)",
                  "PLACE": "linear-gradient(90deg, #ffff00, #ff8c00)",
                  "TIME": "linear-gradient(90deg, #ba9cfc, #ac9ce7)"}
statbot_options = {"ents": ["PER","LOC","ORG","MISC","GRAN","PLACE", "TIME"], "colors": statbot_colors}
spacy.displacy.render(nlp("Ich heisse Christian und war heute in Zürich bei IBM im Internet."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viele Kühe hat die Gemeinde Bülach?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie hoch ist Eigenkapital auf Bezirksebene?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten pro Bezirk"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten für den gesamten Kanton."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viel Bauinv. EFH 5 Jahre  hat  in Regensdorf  ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an MIV-Anteil (Modal Split)   auf Bezirksebene ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   in Flaach ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welches ist das Schül. Sekundarstufe II   für den gesamten Kanton ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welche Gemeinde hat die grösste Bevölkerung?"), style="ent",options=statbot_options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich heisse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  und war heute in Zürich bei
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</div></span>
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/displacy/__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viele Kühe hat die Gemeinde Bülach?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie hoch ist Eigenkapital auf Bezirksebene?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten pro Bezirk</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten für den gesamten Kanton.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viel
# <mark class="entity" style="background: linear-gradient(90deg, #ba9cfc, #ac9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bauinv
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# . EFH 5 Jahre  hat
# <mark class="entity" style="background: linear-gradient(90deg, #ba9cfc, #ac9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  Regensdorf  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an MIV-Anteil (Modal Split)   auf Bezirksebene ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   in Flaach ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welches ist das Schül. Sekundarstufe II   für den gesamten Kanton ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welche Gemeinde hat die grösste Bevölkerung?</div></span>

# %%
#now check the accuracy of our NERs in this plus the next code chunks!


# dictionary to hold our evaluation data
stat_evaluation = {
    "GRAN": {
        "correct": 0,
        "total": 0,
    },
    "PLACE": {
        "correct": 0,
        "total": 0,
    },
    "TIME": {
        "correct": 0,
        "total": 0,
    }
}

word_evaluation = {
    "GRAN": {
        "correct": 0,
        "total": 0
    },
    "PLACE": {
        "correct": 0,
        "total": 0,
    },
    "TIME": {
        "correct": 0,
        "total": 0,
    }

}


for stat in TEST_STAT_DATA:
    # extract the sentence and correct stat entities according to our test data
    sentence = stat[0]
    entities = stat[1]["entities"]

    # for each entity, use our updated model to make a prediction on the sentence
    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]
        n_worded_stat =  len(correct_text.split())
        print(n_worded_stat)

        # if we find that there's a match for predicted entity and predicted text, increment correct counters
        for ent in doc.ents:
            print("ENT_LABEL",ent.label_)
            print("ENTITY2",entity[2])
            print("ENT_TEXT",ent.text)
            print("CORRECT:TEXT",correct_text)
            if ent.label_ == entity[2] and ent.text == correct_text:
                
                stat_evaluation[entity[2]]["correct"] += 1
                if n_worded_stat > 0:
                    word_evaluation[entity[2]]["correct"] += 1

                # this break is important, ensures that we're not double counting on a correct match
                break

        #  increment total counters after each entity loop
        stat_evaluation[entity[2]]["total"] += 1
        if n_worded_stat > 0:
            word_evaluation[entity[2]]["total"] += 1
# Out:
#  TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Katholische Kirchensteuerpflichtige
# 4
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Katholische
# CORRECT:TEXT in Wädenswil bis 2018
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Wädenswil bis 2018
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Katholische
# CORRECT:TEXT von 2006 bis 2013
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT von 2006 bis 2013
# 6
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Bauinv
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Bauinv
# CORRECT:TEXT von 2007 bis 2013
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2007 bis 2013
# 4
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2012
# 4
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Bauinv
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Bauinv
# CORRECT:TEXT von 2013 bis 2018
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2013 bis 2018
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Selbstfinanzierungsanteil
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Anteil Siedlungsfläche
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Anteil Siedlungsfläche
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Geroldswil
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT älteste
# CORRECT:TEXT in Geroldswil
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT pro
# CORRECT:TEXT Bevölkerungszunahme 5 Jahre
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Bevölkerungszunahme 5 Jahre
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT pro
# CORRECT:TEXT pro Gemeinde
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT aktuellste
# CORRECT:TEXT pro Gemeinde
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT pro
# CORRECT:TEXT aktuellste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Sterbefälle
# 1
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT Unterengstringen
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2012
# 6
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT auf
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT auf
# CORRECT:TEXT auf Gemeindeebene
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT auf Gemeindeebene
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT auf
# CORRECT:TEXT in 1998
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 1998
# 6
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Bauinv
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Fällanden
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Bauinv
# CORRECT:TEXT in Fällanden
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Selbstfinanzierungsgrad
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Selbstfinanzierungsgrad
# CORRECT:TEXT Selbstfinanzierungsgrad
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 2
# 2
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Anteil 1Personenhaushalte
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 1970 bis 2000
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Leerwohnungsquote
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Leerwohnungsquote
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Bassersdorf
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT aktuellste
# CORRECT:TEXT in Bassersdorf
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT aktuellste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Neuzulassungen anderer Antrieb
# 1
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT älteste
# CORRECT:TEXT Eglisau
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT KRW Wähleranteil GLP
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT KRW
# CORRECT:TEXT KRW Wähleranteil GLP
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT im
# CORRECT:TEXT Bevölkerungszunahme 1 Jahr
# 3
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT im
# CORRECT:TEXT im Kanton Zürich
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT 15Jahresverbrauch
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 1999
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Anteil GK B
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT für
# CORRECT:TEXT Zinsbelastungsanteil
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Zinsbelastungsanteil
# 3
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT für
# CORRECT:TEXT für alle Bezirke
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT aktuellste
# CORRECT:TEXT für alle Bezirke
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT für
# CORRECT:TEXT aktuellste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Grundsteuern
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Steuerertrag Grundsteuern
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Steuerertrag Grundsteuern
# 3
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Steuerertrag
# CORRECT:TEXT in Bezirk Uster
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Bezirk Uster
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT älteste
# CORRECT:TEXT in Bezirk Uster
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Steuerertrag
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Aeugst
# CORRECT:TEXT Arbeitsstätten im Sekundärsektor
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Arbeitsstätten im Sekundärsektor
# 4
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Aeugst
# CORRECT:TEXT Aeugst a.A. und Schwerzenbach
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT älteste
# CORRECT:TEXT Aeugst a.A. und Schwerzenbach
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Aeugst
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Neuerstellte Wohnungen
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Neuerstellte
# CORRECT:TEXT in 2011
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT pro
# CORRECT:TEXT Hauptberufliche Landwirtschaftsbetriebe
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Hauptberufliche Landwirtschaftsbetriebe
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT pro
# CORRECT:TEXT pro Bezirk
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT aktuellste
# CORRECT:TEXT pro Bezirk
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT pro
# CORRECT:TEXT aktuellste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Altpapiermengen
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2004 bis 2009
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Anteil Gewässerfläche
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Anteil Gewässerfläche
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Kloten
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Kloten
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 1985
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 1985
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Zunahme
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Bestand anderer Antrieb
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2004 bis 2011
# 4
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT 6 und mehr Personenhaushalte
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Henggart
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 1970
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT ÖVAnteil Modal Split
# 4
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT Berg a.I. und Dachsen
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2013
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Landwirtschaftsbetriebe
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT NRW Wähleranteil BDP
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Anteil GK A
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2015 bis 2016
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Bestand Benzinmotor
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT KRW Wähleranteil SVP
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT KRW
# CORRECT:TEXT KRW Wähleranteil SVP
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 4
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Mittlere Betriebe 50249 VZÄ
# 1
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT von
# CORRECT:TEXT Kilchberg
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2018 bis 2018
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Steuerertrag Total
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Steuerertrag Total
# 3
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Region Oberland
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT aktuellste
# CORRECT:TEXT in Region Oberland
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT aktuellste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 4
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2000 bis 2002
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Wanderungsbilanz
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Neftenbach
# CORRECT:TEXT Scheidungen
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Scheidungen
# 3
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Neftenbach
# CORRECT:TEXT Neftenbach und Bauma
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT Neftenbach und Bauma
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Neftenbach
# CORRECT:TEXT in 2012
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2012
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Neuzulassungen Benzinmotor
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Neuzulassungen
# CORRECT:TEXT Neuzulassungen Benzinmotor
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Anteil GK F
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2017
# 1
# 1
# 5
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Steuerb
# CORRECT:TEXT Steuerb. Einkommen natürl. Pers. 25%Quantil
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Russikon
# CORRECT:TEXT Steuerb. Einkommen natürl. Pers. 25%Quantil
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Steuerb. Einkommen natürl. Pers. 25%Quantil
# 3
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Steuerb
# CORRECT:TEXT Russikon und Wiesendangen
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Russikon
# CORRECT:TEXT Russikon und Wiesendangen
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT älteste
# CORRECT:TEXT Russikon und Wiesendangen
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Steuerb
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Russikon
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Steuerkraft
# 4
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Hofstetten bis 2017
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 1992
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT VZÄ im Tertiärsektor
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT VZÄ im Tertiärsektor
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Birmensdorf
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Birmensdorf
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2017
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2017
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Hotelbetten pro Hotel
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2011 bis 2012
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Wahlbeteiligung Nationalrat
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT pro
# CORRECT:TEXT Bauinvestitionen
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT pro
# CORRECT:TEXT pro Gemeinde
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Geb
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Anteil
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Bau
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Anteil
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Anteil
# 7
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Geb
# CORRECT:TEXT Bau und Immobilien und Bau und Immobilien
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Bau
# CORRECT:TEXT Bau und Immobilien und Bau und Immobilien
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT von
# CORRECT:TEXT Bau und Immobilien und Bau und Immobilien
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Geb
# CORRECT:TEXT von 2006 bis 2014
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Bau
# CORRECT:TEXT von 2006 bis 2014
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2006 bis 2014
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Arbeitsstätten im Primärsektor
# 3
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Bezirk Zürich
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT pro
# CORRECT:TEXT Bauzonen überbaut
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Bauzonen überbaut
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT pro
# CORRECT:TEXT pro Bezirk
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT von
# CORRECT:TEXT pro Bezirk
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT pro
# CORRECT:TEXT von 1997 bis 2005
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 1997 bis 2005
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Sozialhilfequote
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Sozialhilfequote
# CORRECT:TEXT Sozialhilfequote
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Anteil
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2005 bis 2018
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT auf
# CORRECT:TEXT 4Personenhaushalte
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT 4Personenhaushalte
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT auf
# CORRECT:TEXT auf Gemeindeebene
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT auf Gemeindeebene
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT auf
# CORRECT:TEXT in 2015
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2015
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Anteil Teilzeitbeschäftigte Landwirtschaft
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 1985 bis 1996
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT NRW Wähleranteil AL
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT NRW Wähleranteil AL
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Egg
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Egg
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2007
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2007
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Maur
# CORRECT:TEXT Steuerkraft berichtigt
# 4
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Maur
# CORRECT:TEXT Maur, Gossau und Weiningen
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT von
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# 4
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT von
# CORRECT:TEXT von 2007 bis 2010
# ENT_LABEL GRAN
# ENTITY2 TIME
# ENT_TEXT Geb.
# CORRECT:TEXT von 2007 bis 2010
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Reingewinn juristische Personen
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Bauinvestitionen
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Bauinvestitionen
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Bauma
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT älteste
# CORRECT:TEXT in Bauma
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT für
# CORRECT:TEXT Beschäftigte im Sekundärsektor
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Beschäftigte im Sekundärsektor
# 4
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT für
# CORRECT:TEXT für den gesamten Kanton
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT älteste
# CORRECT:TEXT für den gesamten Kanton
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT für
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Schafe
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# 3
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Berg a.I.
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2019
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Bevölkerungszunahme 5 Jahre
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 4
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Verkäufe von unbebautem Land
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand
# CORRECT:TEXT Nettoaufwand allgemeine Verwaltung
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT pro
# CORRECT:TEXT Nettoaufwand allgemeine Verwaltung
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Nettoaufwand allgemeine Verwaltung
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Nettoaufwand
# CORRECT:TEXT pro Gemeinde
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT pro
# CORRECT:TEXT pro Gemeinde
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT älteste
# CORRECT:TEXT pro Gemeinde
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Nettoaufwand
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT pro
# CORRECT:TEXT älteste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT auf
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Reformierte
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT auf
# CORRECT:TEXT auf Gemeindeebene
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Reformierte
# CORRECT:TEXT auf Gemeindeebene
# 3
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Bevölkerung: Anteil 014Jährige
# 2
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT in 2007
# 2
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT Neuzulassungen
# CORRECT:TEXT Neuzulassungen  Dieselmotor
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT in
# CORRECT:TEXT Neuzulassungen  Dieselmotor
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT aktuellste
# CORRECT:TEXT Neuzulassungen  Dieselmotor
# 2
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT Neuzulassungen
# CORRECT:TEXT in Regensdorf
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT in
# CORRECT:TEXT in Regensdorf
# ENT_LABEL TIME
# ENTITY2 PLACE
# ENT_TEXT aktuellste
# CORRECT:TEXT in Regensdorf
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT Neuzulassungen
# CORRECT:TEXT aktuellste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT in
# CORRECT:TEXT aktuellste
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT aktuellste
# CORRECT:TEXT aktuellste
# 1
# ENT_LABEL TIME
# ENTITY2 GRAN
# ENT_TEXT älteste
# CORRECT:TEXT Restaurants
# 1
# ENT_LABEL TIME
# ENTITY2 TIME
# ENT_TEXT älteste
# CORRECT:TEXT älteste

# %%
for key in word_evaluation:
    correct = word_evaluation[key]["correct"]
    total = word_evaluation[key]["total"]

    print(f"{key}: {correct / total * 100:.2f}%")

stat_total_sum = 0
stat_correct_sum = 0

print("---")
for key in stat_evaluation:
    correct = stat_evaluation[key]["correct"]
    total = stat_evaluation[key]["total"]
    
    stat_total_sum += total
    stat_correct_sum += correct

    print(f"{key}: {correct / total * 100:.2f}%")

print(f"\nTotal: {stat_correct_sum/stat_total_sum * 100:.2f}%")
# Out:
# GRAN: 0.00%
# PLACE: 0.00%
# TIME: 51.68%
# ---
# GRAN: 0.00%
# PLACE: 0.00%
# TIME: 51.68%
#
# Total: 19.05%

# %%
#now test the accuracy of all the old NERs - was there amnesia on them?

# dictionary which will be populated with the entities and result information
entity_evaluation = {}

# helper function to udpate the entity_evaluation dictionary
def update_results(entity, metric):
    if entity not in entity_evaluation:
        entity_evaluation[entity] = {"correct": 0, "total": 0}
    
    entity_evaluation[entity][metric] += 1

# same as before, see if entities from test set match what spaCy currently predicts
for data in TEST_REVISION_DATA:
    sentence = data[0]
    entities = data[1]["entities"]

    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]

        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                update_results(ent.label_, "correct")
                break

        update_results(entity[2], "total")

# %%
sum_total = 0
sum_correct = 0

for entity in entity_evaluation:
    total = entity_evaluation[entity]["total"]
    correct = entity_evaluation[entity]["correct"]

    sum_total += total
    sum_correct += correct
    
    print("{} | {:.2f}%".format(entity, correct / total * 100))

print()
print("Overall accuracy: {:.2f}%".format(sum_correct / sum_total * 100))
# Out:
# LOC | 39.46%
# MISC | 43.68%
# PER | 87.87%
# ORG | 79.50%
#
# Overall accuracy: 60.99%

# %%
nlp.meta["name"] = "stat_entity_extractor_v0"
nlp.to_disk("./models/v0")

# %%
TRAIN_STAT_DATA[5]
# Out:
# ['Daten für Steuerb. Einkommen natürl. Pers. 25%Quantil aktuellste',
#  {'entities': [[10, 53, 'GRAN'], [54, 64, 'TIME']]}]

# %%
doc = nlp(u'Welche Gemeinde hat die grösste Bevölkerung und welche hatte im 2019 den höchsten Ausländeranteil?')

# show universal pos tags
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.pos_) for t in doc))
# output: Ich/PRON bin/AUX ein/DET Berliner/NOUN ./PUNCT

# show German specific pos tags (STTS)
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.tag_) for t in doc))
# output: Ich/PPER bin/VAFIN ein/ART Berliner/NN ./$.

# show dependency arcs
print('\n'.join('{child:<8} <{label:-^7} {head}'.format(child=t.orth_, label=t.dep_, head=t.head.orth_) for t in doc))
# output: (sb: subject, nk: noun kernel, pd: predicate)

#named entities
print("Named Entity Recognition:")
for ent in doc.ents:
    print(ent.text)
print("Noun chunks:")
for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# Welche/DET Gemeinde/NOUN hat/AUX die/DET grösste/ADJ Bevölkerung/NOUN und/CCONJ welche/PRON hatte/AUX im/ADP 2019/PROPN den/DET höchsten/ADJ Ausländeranteil/NOUN ?/PUNCT
# Welche/PWAT Gemeinde/NN hat/VAFIN die/ART grösste/ADJA Bevölkerung/NN und/KON welche/PDS hatte/VAFIN im/APPRART 2019/CARD den/ART höchsten/ADJA Ausländeranteil/NN ?/$.
# Welche   <--nk--- Gemeinde
# Gemeinde <--sb--- hat
# hat      <-ROOT-- hat
# die      <--nk--- Bevölkerung
# grösste  <--nk--- Bevölkerung
# Bevölkerung <--oa--- hat
# und      <--cd--- Bevölkerung
# welche   <--cj--- und
# hatte    <--cj--- hat
# im       <--mo--- hatte
# 2019     <--nk--- im
# den      <--nk--- Ausländeranteil
# höchsten <--nk--- Ausländeranteil
# Ausländeranteil <--oa--- hatte
# ?        <-punct- hat
# Named Entity Recognition:
# Noun chunks:
# Welche Gemeinde
# die grösste Bevölkerung
# welche
# 2019
# den höchsten Ausländeranteil

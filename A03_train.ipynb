# %% [markdown]
# # 03 Train

# %%
from __future__ import print_function, unicode_literals
import spacy
import warnings
from spacy.util import minibatch, compounding
import de_core_news_lg
import pandas as pd
import numpy as np
from random import sample
import io, csv
import re
import random
import json
from spacy.training import Example
from spacy.tokens import Doc
from tqdm import tqdm
nlp = spacy.load('de_core_news_lg')
#nlp = spacy.load('de_dep_news_trf')

# %%
# helper function for incrementing the revision counters
def increment_revision_counters(entity_counter, entities):
    for entity in entities:
        label = entity[2]
        if label in entity_counter:
            entity_counter[label] += 1
        else:
            entity_counter[label] = 1

# %%
with open('input/tagged_sentences_latest.json') as json_file:
    out_sentences = json.load(json_file)
print("LENGTH OF DATASET: ",len(out_sentences))
dataset_dict={}

for sent in out_sentences:
    entities = sent[1]["entities"]
    increment_revision_counters(dataset_dict, entities)

print(dataset_dict)
# Out:
# LENGTH OF DATASET:  1994
# {'LEVEL_LOC': 276, 'TIME': 1363, 'GRAN': 1975, 'SINGLE_LOC': 886}

# %% [markdown]
# was:
# LENGTH OF DATASET:  1020
# {'DATA': 1010, 'GRAN': 279}
#
# is:
# LENGTH OF DATASET:  1994
# {'GRAN': 1975, 'PLACE': 1108, 'TIME': 1797}
#
# now:
# LENGTH OF DATASET:  1994
# {'GRAN': 1975, 'TIME': 1363, 'LEVEL_LOC': 265, 'SINGLE_LOC': 1035}

# %%
npr_df = pd.read_csv("external/deu_news_2015_3M-sentences.txt", delimiter = "\t")
npr_df = npr_df.sample(frac=1)
npr_df.head()
# Out:
#                1                                                  ­
# 903331    947855  Die Königsblauen einigten sich mit dem 41-Jähr...
# 83590      87108  Allerdings meint Lange auch, dass wir bis zum ...
# 609337    637012  Demnach soll die Behörde veranlassen, dass die...
# 1199967  1262217  Epson warnt, dass gefälschte Projektorlampen e...
# 16099      16452                      3 Leserempfehlungen ein Star.

# %%
# *** <- löschen?
# create an nlp object as we'll use this to seperate the sentences and identify existing entities
#loaded already above
#nlp = spacy.load('de_core_news_lg')

# %%
revision_texts = []

#STAT: Important: THIS IS A HYPER-PARAMETER: Changing it will affect the accuracy of the result
hyper_para_how_many = 100000

# convert the articles to spacy objects to better identify the sentences. Disabled unneeded components. # takes ~ 4 minutes
for doc in tqdm(nlp.pipe(npr_df.iloc[:hyper_para_how_many,1], batch_size=30, disable=["tagger", "ner"])):
    for sentence in doc.sents:

        if  40 < len(sentence.text) < 80:
            # some of the sentences had excessive whitespace in between words, so we're trimming that
            revision_texts.append(" ".join(re.split("\s+", sentence.text, flags=re.UNICODE)))
# Out:
# 100000it [04:23, 380.20it/s]

# %%
revisions = []

# Use the existing spaCy model to predict the entities, then append them to revision
for doc in nlp.pipe(revision_texts, batch_size=50, disable=["tagger", "parser"]):
    
    # don't append sentences that have no entities
    if len(doc.ents) > 0:
        revisions.append((doc.text, {"entities": [(e.start_char, e.end_char, e.label_) for e in doc.ents]}))

# %%
# print an example of the revision sentence
print(revisions[0][0])

# print an example of the revision data
print(revisions[0][1])
# Out:
# Die Königsblauen einigten sich mit dem 41-Jährigen auf einen Vertrag bis
# {'entities': [(4, 16, 'ORG')]}

# %%
# create arrays to store the revision data
TRAIN_REVISION_DATA = []
TEST_REVISION_DATA = []

# create dictionaries to keep count of the different entities
TRAIN_ENTITY_COUNTER = {}
TEST_ENTITY_COUNTER = {}

# This will help distribute the entities (i.e. we don't want 1000 PERSON entities, but only 80 ORG entities)
REVISION_SENTENCE_SOFT_LIMIT = 100



random.shuffle(revisions)
for revision in revisions:
    # get the entities from the revision sentence
    entities = revision[1]["entities"]

    # simple hack to make sure spaCy entities don't get too one-sided
    should_append_to_train_counter = 0
    for _, _, label in entities:
        if label in TRAIN_ENTITY_COUNTER and TRAIN_ENTITY_COUNTER[label] > REVISION_SENTENCE_SOFT_LIMIT:
            should_append_to_train_counter -= 1
        else:
            should_append_to_train_counter += 1

    # simple switch for deciding whether to append to train data or test data
    if should_append_to_train_counter >= 0:
        TRAIN_REVISION_DATA.append(revision)
        increment_revision_counters(TRAIN_ENTITY_COUNTER, entities)
    else:
        TEST_REVISION_DATA.append(revision)
        increment_revision_counters(TEST_ENTITY_COUNTER, entities)

# %%
TRAIN_ENTITY_COUNTER
# Out:
# {'PER': 102, 'ORG': 101, 'MISC': 104, 'LOC': 102}

# %%
TEST_ENTITY_COUNTER
# Out:
# {'MISC': 7427, 'LOC': 7940, 'PER': 7141, 'ORG': 6141}

# %%
#TRAIN_REVISION_DATA

# %%
random.shuffle(out_sentences)
TRAIN_STAT_DATA = out_sentences[:int(len(out_sentences)*0.8)]
TEST_STAT_DATA = out_sentences[int(len(out_sentences)*0.8):]

# %%
print(len(out_sentences))
print(len(TRAIN_STAT_DATA))
print(len(TEST_STAT_DATA))
print("REVISION", len(TRAIN_REVISION_DATA))
TRAIN_DATA = TRAIN_REVISION_DATA + TRAIN_STAT_DATA
print("COMBINED", len(TRAIN_DATA))
# Out:
# 1994
# 1595
# 399
# REVISION 294
# COMBINED 1889

# %%
#STAT: below is the heart piece of this script, and the code was heavily changed compared to the original
#script taken out of the code on deepnote.com. The reason is thaat this code has been adapted to spacy 3 -
#while the old code was running on spacy 2.X
#central command is nlp-update

ner = nlp.get_pipe("ner")

ner.add_label("GRAN")
ner.add_label("LEVEL_LOC")
ner.add_label("SINGLE_LOC")
ner.add_label("TIME")



# get the names of the components we want to disable during training
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# start the training loop, only training NER
epochs = 100
#optimizer = nlp.resume_training()
#optimizer = nlp.initialize()
example_problem_counter = 0

with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
    warnings.filterwarnings("once", category=UserWarning, module='spacy')
    sizes = compounding(1.0, 4.0, 1.001)
    
    # batch up the examples using spaCy's minibatc
    for epoch in range(epochs):
        random.shuffle(TRAIN_DATA)
        #text = []
        #annots=[]
        examples=[]


        for text,annots in TRAIN_DATA:
            #text.append(t)
            #annots.append(a)
            doc = nlp.make_doc(text)
               
            example = Example.from_dict(doc, annots)
            examples.append(example)
               # example_problem_counter += 1
        
        losses = {}
        
        nlp.update(examples, drop=0.35, losses=losses)#,sgd=optimizer)

        print("Losses ({}/{})".format(epoch + 1, epochs), losses)
# Out:
# 9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Ich brauche NRW Waehleranteil EVP in Prozent Walta..." with entities "[[12, 33, 'GRAN'], [45, 57, 'SINGLE_LOC'], [57, 74...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist das Steuerb. Einkommen natuerl. Pers. 75%Q..." with entities "[[68, 75, 'SINGLE_LOC'], [76, 93, 'TIME'], [12, 56...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Wie viel Steuerkraft pro Kopf hat Wettswil a.A. un..." with entities "[[34, 47, 'SINGLE_LOC'], [52, 64, 'SINGLE_LOC'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist der Anteil an Bevoelkerungszunahme 5 Jahre..." with entities "[[22, 50, 'GRAN'], [65, 69, 'TIME'], [51, 65, 'SIN...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "In Wetzikon und Kyburg wie hoch war Bauinv. EFH 5 ..." with entities "[[36, 55, 'GRAN'], [3, 11, 'SINGLE_LOC'], [16, 23,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Welches ist das Nettoinvestitionen Bezirk Pfaeffik..." with entities "[[16, 34, 'GRAN'], [69, 79, 'TIME'], [57, 69, 'SIN...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Wie viel Steuerertrag Total hat Unterstammheim von..." with entities "[[9, 27, 'GRAN'], [47, 64, 'TIME'], [32, 47, 'SING...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist das Ø steuerbares Vermoegen natuerliche Pe..." with entities "[[54, 61, 'SINGLE_LOC'], [12, 53, 'GRAN'], [65, 72...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Wie viel Schweine hat Waltalingen und Andelfingen ..." with entities "[[50, 60, 'TIME'], [38, 49, 'SINGLE_LOC'], [9, 17,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Wie viel Erwerb des Schweizer Buergerrechts hat Ky..." with entities "[[9, 43, 'GRAN'], [48, 55, 'SINGLE_LOC']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Wie viel Bauinvestitionen hat Hofstetten 2012 ?" with entities "[[30, 41, 'SINGLE_LOC'], [9, 25, 'GRAN'], [41, 45,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Wie viel Beschaeftigte im Tertiaersektor hat Obers..." with entities "[[9, 40, 'GRAN'], [45, 59, 'SINGLE_LOC']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist der Anteil von Bestand Dieselmotor Hofstet..." with entities "[[43, 54, 'SINGLE_LOC'], [23, 42, 'GRAN'], [58, 70...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist der Anteil an Bezuegerquote der bedarfsabh..." with entities "[[22, 68, 'GRAN'], [94, 111, 'TIME'], [69, 80, 'SI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "In Schlatt und Elgg wie hoch war Kehrichtmengen?" with entities "[[3, 10, 'SINGLE_LOC'], [33, 47, 'GRAN'], [15, 20,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Welches ist das Steuerertrag Total Bauma und Oetwi..." with entities "[[16, 34, 'GRAN'], [45, 58, 'SINGLE_LOC'], [59, 63...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist das Arbeitsstaetten im Tertiaersektor Horg..." with entities "[[46, 53, 'SINGLE_LOC'], [12, 45, 'GRAN'], [57, 67...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "In Bauma wie hoch war Nettoaufwand Volkswirtschaft..." with entities "[[22, 50, 'GRAN'], [3, 9, 'SINGLE_LOC']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Wie viel Erwerb des Schweizer Buergerrechts hat Ho..." with entities "[[9, 43, 'GRAN'], [48, 55, 'SINGLE_LOC'], [55, 72,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Welches ist das Nettovermoegen Zumikon und Bauma a..." with entities "[[49, 59, 'TIME'], [31, 38, 'SINGLE_LOC'], [16, 30...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist der Anteil an KRW Waehleranteil EDU Kyburg..." with entities "[[70, 74, 'TIME'], [22, 43, 'GRAN'], [44, 51, 'SIN...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist das Steuerertrag Total Bauma aelteste?" with entities "[[12, 30, 'GRAN'], [31, 37, 'SINGLE_LOC']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Welches ist das Schuel. Oberstufe Sternenberg und ..." with entities "[[34, 46, 'SINGLE_LOC'], [16, 33, 'GRAN']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "In Ossingen und Waltalingen wie hoch war Wasserver..." with entities "[[3, 11, 'SINGLE_LOC'], [16, 28, 'SINGLE_LOC'], [4...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Ich brauche NRW Waehleranteil SP in Prozent Sterne..." with entities "[[56, 66, 'TIME'], [44, 56, 'SINGLE_LOC'], [12, 32...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Welches ist das Weg zur naechsten Haltestelle Rues..." with entities "[[16, 45, 'GRAN'], [74, 91, 'TIME'], [62, 74, 'SIN...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist der Anteil von Jugendquotient Truttikon un..." with entities "[[52, 59, 'SINGLE_LOC'], [38, 47, 'SINGLE_LOC'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist das Weg zur naechsten Haltestelle Waltalin..." with entities "[[54, 58, 'TIME'], [42, 54, 'SINGLE_LOC'], [12, 41...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Wie viel Arbeitslose hat Pfaeffikon und Oberstammh..." with entities "[[9, 20, 'GRAN'], [40, 54, 'SINGLE_LOC'], [54, 71,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "In Hofstetten und Region Zuerich wie hoch war Bauz..." with entities "[[3, 14, 'SINGLE_LOC'], [46, 73, 'GRAN']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "In Hinwil und Bauma wie hoch war Erwerb des Schwei..." with entities "[[33, 67, 'GRAN'], [14, 20, 'SINGLE_LOC'], [3, 9, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist das Steuerbares Vermoegen natuerliche Pers..." with entities "[[52, 59, 'SINGLE_LOC'], [12, 51, 'GRAN'], [59, 69...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/robe/Downloads/other/hackathon_mar21/virtenv/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Was ist das Flaeche Unterstammheim von 1997 bis 20..." with entities "[[12, 19, 'GRAN'], [20, 35, 'SINGLE_LOC'], [35, 52...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses (1/100) {'ner': 7709.121697278492}
# Losses (2/100) {'ner': 7325.782699823606}
# Losses (3/100) {'ner': 7022.092537118897}
# Losses (4/100) {'ner': 6723.181297273011}
# Losses (5/100) {'ner': 6473.82089904329}
# Losses (6/100) {'ner': 6432.725299287558}
# Losses (7/100) {'ner': 6173.575053762179}
# Losses (8/100) {'ner': 5940.919400341809}
# Losses (9/100) {'ner': 5809.082900935784}
# Losses (10/100) {'ner': 5787.836839877069}
# Losses (11/100) {'ner': 5736.401120273396}
# Losses (12/100) {'ner': 5623.617335284129}
# Losses (13/100) {'ner': 5612.845858054236}
# Losses (14/100) {'ner': 5490.982026003301}
# Losses (15/100) {'ner': 5552.689499744214}
# Losses (16/100) {'ner': 5433.233781544957}
# Losses (17/100) {'ner': 5367.753615433816}
# Losses (18/100) {'ner': 5365.793095958186}
# Losses (19/100) {'ner': 5195.073264249368}
# Losses (20/100) {'ner': 4993.02339792384}
# Losses (21/100) {'ner': 4929.054347472309}
# Losses (22/100) {'ner': 4770.709079275752}
# Losses (23/100) {'ner': 4748.097087970644}
# Losses (24/100) {'ner': 4649.663952022209}
# Losses (25/100) {'ner': 4917.413830044694}
# Losses (26/100) {'ner': 4710.116339660469}
# Losses (27/100) {'ner': 4575.039008743372}
# Losses (28/100) {'ner': 4628.093525586416}
# Losses (29/100) {'ner': 4610.4752341137955}
# Losses (30/100) {'ner': 4535.2851416894355}
# Losses (31/100) {'ner': 4508.494804691002}
# Losses (32/100) {'ner': 4439.494826636213}
# Losses (33/100) {'ner': 4732.571335973633}
# Losses (34/100) {'ner': 4667.96415000814}
# Losses (35/100) {'ner': 4822.4434468880845}
# Losses (36/100) {'ner': 4829.469641513244}
# Losses (37/100) {'ner': 5108.901161909103}
# Losses (38/100) {'ner': 4910.594394207001}
# Losses (39/100) {'ner': 5039.31289601326}
# Losses (40/100) {'ner': 5075.229512810707}
# Losses (41/100) {'ner': 4963.272889850719}
# Losses (42/100) {'ner': 5070.17869758606}
# Losses (43/100) {'ner': 4806.045314498491}
# Losses (44/100) {'ner': 5065.449714770861}
# Losses (45/100) {'ner': 5017.185258309695}
# Losses (46/100) {'ner': 4788.229529363896}
# Losses (47/100) {'ner': 4664.097941715496}
# Losses (48/100) {'ner': 4574.9464338386315}
# Losses (49/100) {'ner': 4717.046724438667}
# Losses (50/100) {'ner': 4418.347792625427}
# Losses (51/100) {'ner': 4368.499772200128}
# Losses (52/100) {'ner': 4150.83086812876}
# Losses (53/100) {'ner': 4057.8008901617777}
# Losses (54/100) {'ner': 3800.5003505200802}
# Losses (55/100) {'ner': 3676.925482867733}
# Losses (56/100) {'ner': 3436.9515243030983}
# Losses (57/100) {'ner': 3379.255422592163}
# Losses (58/100) {'ner': 3213.6312368478166}
# Losses (59/100) {'ner': 3069.8746095001115}
# Losses (60/100) {'ner': 2934.0012151523483}
# Losses (61/100) {'ner': 2711.6695746310997}
# Losses (62/100) {'ner': 2692.6631672035655}
# Losses (63/100) {'ner': 2620.298320686674}
# Losses (64/100) {'ner': 2457.028883255754}
# Losses (65/100) {'ner': 2346.4887927107375}
# Losses (66/100) {'ner': 2352.5641672108413}
# Losses (67/100) {'ner': 2341.0480862699605}
# Losses (68/100) {'ner': 2194.1490027915725}
# Losses (69/100) {'ner': 2161.6779343063245}
# Losses (70/100) {'ner': 2024.465645785055}
# Losses (71/100) {'ner': 1941.320886089935}
# Losses (72/100) {'ner': 1915.2173797451046}
# Losses (73/100) {'ner': 1820.621274254913}
# Losses (74/100) {'ner': 1764.042115009077}
# Losses (75/100) {'ner': 1676.4816201232438}
# Losses (76/100) {'ner': 1599.6860740138945}
# Losses (77/100) {'ner': 1502.8554304142508}
# Losses (78/100) {'ner': 1372.2265726937928}
# Losses (79/100) {'ner': 1300.083086068751}
# Losses (80/100) {'ner': 1315.7808947997978}
# Losses (81/100) {'ner': 1262.6764487808923}
# Losses (82/100) {'ner': 1092.5528905242313}
# Losses (83/100) {'ner': 1061.2714943873384}
# Losses (84/100) {'ner': 937.0210815507315}
# Losses (85/100) {'ner': 893.1708317779189}
# Losses (86/100) {'ner': 910.2644415789542}
# Losses (87/100) {'ner': 808.1936813309643}
# Losses (88/100) {'ner': 748.8919489245884}
# Losses (89/100) {'ner': 681.0090212530938}
# Losses (90/100) {'ner': 685.4164839554743}
# Losses (91/100) {'ner': 677.0826773707962}
# Losses (92/100) {'ner': 668.2123255478889}
# Losses (93/100) {'ner': 607.731983085516}
# Losses (94/100) {'ner': 622.440395585344}
# Losses (95/100) {'ner': 459.92663061656515}
# Losses (96/100) {'ner': 463.1818600358838}
# Losses (97/100) {'ner': 427.1636134548422}
# Losses (98/100) {'ner': 419.68703184227803}
# Losses (99/100) {'ner': 407.8679631754835}
# Losses (100/100) {'ner': 352.55023878139696}

# %%
statbot_colors = {"LEVEL_LOC": "linear-gradient(90deg, #aa9cfc, #fc9ce7)",
                  "SINGLE_LOC": "linear-gradient(90deg, #ffff00, #ff8c00)",
                  "GRAN": "linear-gradient(90deg, #ffff00, #ff8c00)",
                  "TIME": "linear-gradient(90deg, #aaf6b1, #99dd9f)"}
statbot_options = {"ents": ["PER","LOC","ORG","MISC","LEVEL_LOC","SINGLE_LOC", "TIME"], "colors": statbot_colors}
spacy.displacy.render(nlp("Ich heisse Christian und war heute in Zürich bei IBM im Internet."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viele Kühe hat die Gemeinde Bülach aktuell?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie hoch ist Eigenkapital auf Bezirksebene?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten pro Bezirk"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten für den gesamten Kanton älteste."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viel Bauinv. EFH 5 Jahre  hat  in Regensdorf  neueste?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an MIV-Anteil (Modal Split)  älteste  auf Bezirksebene ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme in Flaach in 2017 ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welches ist das Schül. Sekundarstufe II für den gesamten Kanton von 2013 bis 2018?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welche Gemeinde hat die grösste Bevölkerung?"), style="ent",options=statbot_options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich heisse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  und war heute in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  bei
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viele Kühe hat die
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemeinde Bülach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SINGLE_LOC</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(90deg, #aaf6b1, #99dd9f); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aktuell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie hoch ist Eigenkapital
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     auf Bezirksebene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEVEL_LOC</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pro Bezirk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEVEL_LOC</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten für den gesamten Kanton älteste.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viel Bauinv. EFH 5 Jahre  hat  in
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SINGLE_LOC</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(90deg, #aaf6b1, #99dd9f); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     neueste
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an MIV-Anteil (Modal Split)  älteste
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     auf Bezirksebene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LEVEL_LOC</span>
# </mark>
#  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme in
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Flaach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SINGLE_LOC</span>
# </mark>
#  in
# <mark class="entity" style="background: linear-gradient(90deg, #aaf6b1, #99dd9f); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welches ist das Schül. Sekundarstufe II für den gesamten Kanton
# <mark class="entity" style="background: linear-gradient(90deg, #aaf6b1, #99dd9f); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     von 2013 bis 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welche Gemeinde hat die grösste Bevölkerung?</div></span>

# %%
#now check the accuracy of our NERs in this plus the next code chunks!


# dictionary to hold our evaluation data
stat_evaluation = {
    "LEVEL_LOC": {
        "correct": 0,
        "total": 0,
    },
    "SINGLE_LOC": {
        "correct": 0,
        "total": 0,
    },
    "TIME": {
        "correct": 0,
        "total": 0,
    }
}

word_evaluation = {
    "LEVEL_LOC": {
        "correct": 0,
        "total": 0
    },
    "SINGLE_LOC": {
        "correct": 0,
        "total": 0,
    },
    "TIME": {
        "correct": 0,
        "total": 0,
    }

}


for stat in TEST_STAT_DATA:
    # extract the sentence and correct stat entities according to our test data
    sentence = stat[0]
    entities = stat[1]["entities"]

    # for each entity, use our updated model to make a prediction on the sentence
    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]
        n_worded_stat =  len(correct_text.split())
        print(n_worded_stat)

        # if we find that there's a match for predicted entity and predicted text, increment correct counters
        for ent in doc.ents:
            print("ENT_LABEL",ent.label_)
            print("ENTITY2",entity[2])
            print("ENT_TEXT",ent.text)
            print("CORRECT:TEXT",correct_text)
            if ent.label_ == entity[2] and ent.text == correct_text:
                
                stat_evaluation[entity[2]]["correct"] += 1
                if n_worded_stat > 0:
                    word_evaluation[entity[2]]["correct"] += 1

                # this break is important, ensures that we're not double counting on a correct match
                break

        #  increment total counters after each entity loop
        stat_evaluation[entity[2]]["total"] += 1
        if n_worded_stat > 0:
            word_evaluation[entity[2]]["total"] += 1
# Out:
# 3
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil SVP
# ENT_LABEL SINGLE_LOC
# ENTITY2 GRAN
# ENT_TEXT Dorf
# CORRECT:TEXT NRW Waehleranteil SVP
# ENT_LABEL SINGLE_LOC
# ENTITY2 GRAN
# ENT_TEXT Erlenbach
# CORRECT:TEXT NRW Waehleranteil SVP
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-7f39500e42a3> in <module>
#      63
#      64         #  increment total counters after each entity loop
# ---> 65         stat_evaluation[entity[2]]["total"] += 1
#      66         if n_worded_stat > 0:
#      67             word_evaluation[entity[2]]["total"] += 1
#
# KeyError: 'GRAN'

# %%
for key in word_evaluation:
    correct = word_evaluation[key]["correct"]
    total = word_evaluation[key]["total"]

    print(f"{key}: {correct / total * 100:.2f}%")

stat_total_sum = 0
stat_correct_sum = 0

print("---")
for key in stat_evaluation:
    correct = stat_evaluation[key]["correct"]
    total = stat_evaluation[key]["total"]
    
    stat_total_sum += total
    stat_correct_sum += correct

    print(f"{key}: {correct / total * 100:.2f}%")

print(f"\nTotal: {stat_correct_sum/stat_total_sum * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-100-6344f51f5bc6> in <module>
#       3     total = word_evaluation[key]["total"]
#       4
# ----> 5     print(f"{key}: {correct / total * 100:.2f}%")
#       6
#       7 stat_total_sum = 0
#
# ZeroDivisionError: division by zero

# %%
#now test the accuracy of all the old NERs - was there amnesia on them?

# dictionary which will be populated with the entities and result information
entity_evaluation = {}

# helper function to udpate the entity_evaluation dictionary
def update_results(entity, metric):
    if entity not in entity_evaluation:
        entity_evaluation[entity] = {"correct": 0, "total": 0}
    
    entity_evaluation[entity][metric] += 1

# same as before, see if entities from test set match what spaCy currently predicts
for data in TEST_REVISION_DATA:
    sentence = data[0]
    entities = data[1]["entities"]

    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]

        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                update_results(ent.label_, "correct")
                break

        update_results(entity[2], "total")

# %%
sum_total = 0
sum_correct = 0

for entity in entity_evaluation:
    total = entity_evaluation[entity]["total"]
    correct = entity_evaluation[entity]["correct"]

    sum_total += total
    sum_correct += correct
    
    print("{} | {:.2f}%".format(entity, correct / total * 100))

print()
print("Overall accuracy: {:.2f}%".format(sum_correct / sum_total * 100))
# Out:
# MISC | 63.73%
# LOC | 66.25%
# PER | 83.36%
# ORG | 80.05%
#
# Overall accuracy: 72.82%

# %%
nlp.meta["name"] = "stat_entity_extractor_v0"
nlp.to_disk("./models/v0")

# %%
TRAIN_STAT_DATA[5]
# Out:
# ['Daten für Steuerb. Einkommen natürl. Pers. 25%Quantil aktuellste',
#  {'entities': [[10, 53, 'GRAN'], [54, 64, 'TIME']]}]

# %%
doc = nlp(u'Welche Gemeinde hat die grösste Bevölkerung und welche hatte im 2019 den höchsten Ausländeranteil?')

# show universal pos tags
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.pos_) for t in doc))
# output: Ich/PRON bin/AUX ein/DET Berliner/NOUN ./PUNCT

# show German specific pos tags (STTS)
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.tag_) for t in doc))
# output: Ich/PPER bin/VAFIN ein/ART Berliner/NN ./$.

# show dependency arcs
print('\n'.join('{child:<8} <{label:-^7} {head}'.format(child=t.orth_, label=t.dep_, head=t.head.orth_) for t in doc))
# output: (sb: subject, nk: noun kernel, pd: predicate)

#named entities
print("Named Entity Recognition:")
for ent in doc.ents:
    print(ent.text)
print("Noun chunks:")
for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# Welche/DET Gemeinde/NOUN hat/AUX die/DET grösste/ADJ Bevölkerung/NOUN und/CCONJ welche/PRON hatte/AUX im/ADP 2019/PROPN den/DET höchsten/ADJ Ausländeranteil/NOUN ?/PUNCT
# Welche/PWAT Gemeinde/NN hat/VAFIN die/ART grösste/ADJA Bevölkerung/NN und/KON welche/PDS hatte/VAFIN im/APPRART 2019/CARD den/ART höchsten/ADJA Ausländeranteil/NN ?/$.
# Welche   <--nk--- Gemeinde
# Gemeinde <--sb--- hat
# hat      <-ROOT-- hat
# die      <--nk--- Bevölkerung
# grösste  <--nk--- Bevölkerung
# Bevölkerung <--oa--- hat
# und      <--cd--- Bevölkerung
# welche   <--cj--- und
# hatte    <--cj--- hat
# im       <--mo--- hatte
# 2019     <--nk--- im
# den      <--nk--- Ausländeranteil
# höchsten <--nk--- Ausländeranteil
# Ausländeranteil <--oa--- hatte
# ?        <-punct- hat
# Named Entity Recognition:
# Noun chunks:
# Welche Gemeinde
# die grösste Bevölkerung
# welche
# 2019
# den höchsten Ausländeranteil
